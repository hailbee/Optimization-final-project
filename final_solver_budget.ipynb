# %% [markdown]
# Solver

# %%
using JuMP
using Gurobi
using CSV
using DataFrames
using Plots

# %% [markdown]
# Data Importation

# %%
budgets_demand = CSV.File("./data/budgets_demand.csv",header=0) |> Tables.matrix;
impression_data = CSV.File("./data/impression_per_age.csv",header=0) |> Tables.matrix; # plaform, age group, impressions rate
company_rcs_data = CSV.File("./data/company_rcs.csv",header=0) |> Tables.matrix; # company, rps
platform_variables_data = CSV.File("./data/platform_variables.csv",header=0) |> Tables.matrix; # platform, variable, value

# %% [markdown]
# Clean Data

# %%
# define dictionaries to use

# B: budget
budget_dict = Dict() # dict of (company) -> budget; 50 companies
for i in 2:size(budgets_demand,1)
    budget_dict[budgets_demand[i, 1]] = parse(Int, budgets_demand[i, 2])
end

# R_a: total reach demanded for each age group
demand_dict = Dict() # dict of (company, age group) -> demand; 50 companies, 4 age groups
age_groups = ["18-24", "25-34", "35-44", "45-60"]
for i in 2:size(budgets_demand,1)
    for j in 3:size(budgets_demand,2)
        demand_dict[(budgets_demand[i, 1], budgets_demand[1,j])] = parse(Int, budgets_demand[i,j])
    end
end

# impression rate per age group (a_ap*i_p)
impressions_per_age = Dict() # dict of (platform, age group) -> impression rate
for i in 2:size(impression_data,1)
    str_value = string(impression_data[i, 3])  # Convert to regular String
    impressions_per_age[(impression_data[i, 1], impression_data[i, 2])] = parse(Float64, str_value)  # Parse to Int
end


# company revenue per conversion
company_rcs = Dict() # dict of company -> r_c
for i in 1:size(company_rcs_data,2)
    # row 1 is company name, row 2 is r_c
    company_rcs[company_rcs_data[1, i]] = parse(Float64, company_rcs_data[2, i])
end

# platform variables
# constant for all companies need for each platform, 
    # w_p: click_rate
    # i_p: impression_rate
    # f_p: average_impression_rate
    # c_p: conversion rate
    # s_p: cost per click 

platform_variables = Dict() # dict of (platform, variable) -> value
for i in 2:size(platform_variables_data, 2)
    for j in 2:size(platform_variables_data, 1)
        platform_variables[platform_variables_data[1, i], platform_variables_data[j, 1]] = parse(Float64, platform_variables_data[j, i])
    end
end

# %%
const GRB_ENV = Gurobi.Env(output_flag=1);
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-09-08
# WARNING: redefinition of constant Main.GRB_ENV. This may fail, cause incorrect answers, or produce other errors.

# %% [markdown]
# Solver

# %%
platforms_l = ["Facebook", "Instagram", "Twitter"] # keept this order
companies_l = collect(keys(budget_dict)) # keept this order
age_groups = ["18-24", "25-34", "35-44", "45-60"]


# model for each company
optimized_solutions= Dict() # dict of company -> {t -> [t_p], optimal_value -> value}

for i in 1:length(companies_l)
    company = companies_l[i]
    println("Optimizing for company: ", company)
    model = Model(() -> Gurobi.Optimizer(GRB_ENV))

    ### decision variable ###
    # hours of advertisement allocated to platform p by company c: t_p
    @variable(model, t[1:length(platforms_l)] >= 0);

    ### constraints ###
    # reach for certain age group must reach a min
    @constraint(model, demand_constraints[a in 1:length(age_groups)], sum(((impressions_per_age[platforms_l[p], age_groups[a]] * t[p])/platform_variables[platforms_l[p], "f_p"] for p in 1:length(platforms_l))) >= demand_dict[company, age_groups[a]]);

    # budget constraint
    # @constraint(model, sum(platform_variables[platforms_l[p], "s_p"] * (platform_variables[platforms_l[p], "w_p"]*(platform_variables[platforms_l[p], "i_p"]*t[p])/platform_variables[platforms_l[p], "f_p"]) for p in 1:length(platforms_l)) <= budget_dict[company]);


    ### objective function ### 
    @objective(model, Min,
    sum((
        sum(platform_variables[platforms_l[p], "s_p"] * (platform_variables[platforms_l[p], "w_p"]*(platform_variables[platforms_l[p], "i_p"]*t[p])/platform_variables[platforms_l[p], "f_p"]) for p in 1:length(platforms_l)))
    ));

    optimize!(model)
    optimized_solutions[company] = Dict()


    dual_values = [dual(demand_constraints[a]) for a in 1:length(age_groups)]

    try
        optimized_solutions[company]["optimal_budget"] = objective_value(model)
        optimized_solutions[company]["t"] = value.(t)
        optimized_solutions[company]["dual_values"] = dual_values
    catch e
        optimized_solutions[company]["optimal_budget"] = -1 # no solution
        optimized_solutions[company]["t"] = -1
    end
end
# Out:
# Optimizing for company: Silk & Style
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x94f3c9af
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.702000e+03   0.000000e+00      0s
#        3    1.4200969e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.420096873e+03
#
# User-callback calls 44, time in user-callback 0.00 sec
# Optimizing for company: Vogue Visions
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xbafe5515
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.398750e+03   0.000000e+00      0s
#        3    1.2272585e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.227258492e+03
#
# User-callback calls 44, time in user-callback 0.00 sec
# Optimizing for company: Hearth Harmony
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xebf8bf20
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 5e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.387500e+02   0.000000e+00      0s
#        1    1.3679654e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.367965433e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Silicon Saga
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xdf57c436
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.764000e+03   0.000000e+00      0s
#        2    1.8539466e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.853946573e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Furnish Fine
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x810415f9
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.861750e+03   0.000000e+00      0s
#        3    1.5184561e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.518456055e+03
#
# User-callback calls 44, time in user-callback 0.00 sec
# Optimizing for company: Gastronomy Guild
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xcc8dc2b6
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.885000e+03   0.000000e+00      0s
#        1    2.5005820e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.500581975e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Dwell Delight
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x7f2dd8f6
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.798500e+03   0.000000e+00      0s
#        3    2.2328726e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.232872611e+03
#
# User-callback calls 44, time in user-callback 0.00 sec
# Optimizing for company: Cozy Corners
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x94732786
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.845000e+02   0.000000e+00      0s
#        3    1.0597630e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.059763030e+03
#
# User-callback calls 44, time in user-callback 0.00 sec
# Optimizing for company: Fitness Front
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x0182b193
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.552500e+03   0.000000e+00      0s
#        1    2.3740819e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.374081946e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Pixel Pioneers
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x919a08f8
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+00, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.175250e+03   0.000000e+00      0s
#        1    2.4240936e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.424093585e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Vigor Valley
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xf7925888
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.369500e+03   0.000000e+00      0s
#        1    2.1652098e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.165209804e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Dine Divine
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x2af34862
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.007500e+03   0.000000e+00      0s
#        1    1.6356748e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.635674798e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Heal Hub
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x150f907c
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.036000e+03   0.000000e+00      0s
#        2    1.0557661e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.055766058e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Fiber Fashion
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x064cbcc7
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.480250e+03   0.000000e+00      0s
#        2    1.4532385e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.453238463e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Quantum Quirks
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xc66afa1f
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.885000e+02   0.000000e+00      0s
#        2    1.4292536e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.429253610e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Tech Titans
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x2a40ccd4
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.225500e+03   0.000000e+00      0s
#        1    2.4211517e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.421151724e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Trend Tailors
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x98bf529e
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+02, 7e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.513000e+03   0.000000e+00      0s
#        1    2.2034540e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.203453999e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Innovate Infinity
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x7790592f
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.404250e+03   0.000000e+00      0s
#        2    1.1678888e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.167888826e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Runway Rebels
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x16b77b85
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+01, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.007500e+02   0.000000e+00      0s
#        3    8.6034101e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  8.603410052e+02
#
# User-callback calls 44, time in user-callback 0.00 sec
# Optimizing for company: Giga Geeks
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xe4547a4a
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.722500e+02   0.000000e+00      0s
#        2    1.0890608e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.089060832e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Palate Paradise
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x6ce81a4c
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.454500e+03   0.000000e+00      0s
#        1    2.6300239e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.630023865e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Homely Haven
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x18a1bd1c
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+02, 7e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.509750e+03   0.000000e+00      0s
#        2    1.7725162e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.772516162e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Attire Artistry
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x1f3d87a7
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   8.622500e+02   0.000000e+00      0s
#        1    1.6621515e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.662151548e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Culinary Quest
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xd6ff2f6b
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.393250e+03   0.000000e+00      0s
#        1    1.3603228e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.360322763e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Nest Neat
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xa832a75f
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 7e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   9.307500e+02   0.000000e+00      0s
#        1    1.0388195e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.038819501e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Domestic Dream
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x3819926a
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.168000e+03   0.000000e+00      0s
#        1    1.2769139e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.276913898e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Mode Maven
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x2a30de85
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 5e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.525000e+02   0.000000e+00      0s
#        1    7.3399801e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  7.339980126e+02
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Epicurean Edge
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x95a55594
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.657250e+03   0.000000e+00      0s
#        1    1.4952935e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.495293472e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Pulse Point
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xb294f275
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.531750e+03   0.000000e+00      0s
#        2    1.3831387e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.383138684e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Code Crafters
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xde2f6ff1
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.532000e+03   0.000000e+00      0s
#        2    1.2615925e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.261592464e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Feast Flavors
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xf4ae91f1
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.085000e+02   0.000000e+00      0s
#        2    1.2201868e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.220186789e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Space Spruce
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x9e6242b6
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.456500e+03   0.000000e+00      0s
#        1    1.3193766e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.319376593e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Nosh Nirvana
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xfbd8d88b
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+01, 4e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   6.725000e+02   0.000000e+00      0s
#        2    6.0354831e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  6.035483052e+02
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Style Sphere
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x2b7d1759
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 7e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.238750e+03   0.000000e+00      0s
#        2    1.0494021e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.049402056e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Cyber Circuit
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xe5ffe4ba
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e+01, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   2.003750e+03   0.000000e+00      0s
#        2    2.5552829e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.555282930e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Gourmet Grove
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x3d4e5f32
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.350750e+03   0.000000e+00      0s
#        1    2.2534656e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.253465639e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Well Wish
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x1d447c63
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [8e+01, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.507250e+03   0.000000e+00      0s
#        1    1.3785211e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.378521061e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: NexGen Nerds
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xf159fc9a
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+02, 7e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.077750e+03   0.000000e+00      0s
#        1    1.3267794e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.326779377e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Glam Garments
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x0a722c3d
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.538000e+03   0.000000e+00      0s
#        1    2.2063959e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.206395860e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Balance Beam
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x607c1b78
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [9e+01, 7e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.139500e+03   0.000000e+00      0s
#        1    1.7003957e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.700395743e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Wellness Waves
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x13bafd86
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.592250e+03   0.000000e+00      0s
#        1    2.8153611e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.815361118e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Aura Align
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x02e81478
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+01, 6e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.182500e+02   0.000000e+00      0s
#        2    6.8830774e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  6.883077365e+02
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Bistro Bliss
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x3dbae7b5
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+01, 6e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.640000e+02   0.000000e+00      0s
#        4    6.8646392e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  6.864639236e+02
#
# User-callback calls 45, time in user-callback 0.00 sec
# Optimizing for company: Savor Street
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xf1a9b24d
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.370750e+03   0.000000e+00      0s
#        1    2.4770471e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.477047086e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Living Luxe
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x3659af6f
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 8e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.323750e+03   0.000000e+00      0s
#        1    1.1692406e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.169240636e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Elixir Essence
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x722eb474
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e+00, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.193000e+03   0.000000e+00      0s
#        1    1.4513143e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  1.451314252e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Gadget Giants
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x9db84046
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+01, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   7.750000e+02   0.000000e+00      0s
#        2    9.6327683e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  9.632768342e+02
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Vital Vigor
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x672560f0
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+02, 9e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.796250e+03   0.000000e+00      0s
#        2    2.3221290e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.322129006e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Decor Dreams
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0x3e5899e4
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [5e+02, 1e+03]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   1.594000e+03   0.000000e+00      0s
#        1    2.2416982e+03   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  2.241698194e+03
#
# User-callback calls 42, time in user-callback 0.00 sec
# Optimizing for company: Chic Couture
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (mac64[arm] - Darwin 23.5.0 23F79)
#
# CPU model: Apple M2 Pro
# Thread count: 12 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4 rows, 3 columns and 12 nonzeros
# Model fingerprint: 0xda86da54
# Coefficient statistics:
#   Matrix range     [6e-01, 3e+00]
#   Objective range  [2e+00, 3e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 3e+02]
# Presolve time: 0.00s
# Presolved: 4 rows, 3 columns, 12 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   4.575000e+02   0.000000e+00      0s
#        1    5.2471759e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.247175876e+02
#
# User-callback calls 42, time in user-callback 0.00 sec

# %%
for (company, solution) in optimized_solutions
    println("Company: ", company)
    println("Proposed budget: ", solution["optimal_budget"])
    println("Optimal t: ", solution["t"])
    println("Dual values: ", solution["dual_values"])
    println()
end
# Out:
# Company: Silk & Style
# Proposed budget: 1420.0968729971398
# Optimal t: [101.70753826743362, 69.7424839564212, 434.3231083638419]
# Dual values: [1.3310067988139078, 0.5333618956639448, 0.0, 0.36922177377979787]
#
# Company: Vogue Visions
# Proposed budget: 1227.258491751657
# Optimal t: [0.0, 174.47562427981862, 335.7126606225467]
# Dual values: [2.818622454011731, 0.0, 0.08039597348061467, 0.0]
#
# Company: Hearth Harmony
# Proposed budget: 1367.9654333968488
# Optimal t: [0.0, 517.9866195764649, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Silicon Saga
# Proposed budget: 1853.9465729011915
# Optimal t: [0.0, 442.65064352741, 299.9975193002428]
# Dual values: [2.8171893853441636, 0.11538566993997924, 0.0, 0.0]
#
# Company: Furnish Fine
# Proposed budget: 1518.456054800027
# Optimal t: [12.900600076853307, 9.105941637057116, 640.9675356830581]
# Dual values: [1.3310067988139078, 0.5333618956639448, 0.0, 0.36922177377979787]
#
# Company: Gastronomy Guild
# Proposed budget: 2500.581975026498
# Optimal t: [0.0, 946.8572615913876, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Dwell Delight
# Proposed budget: 2232.8726106413083
# Optimal t: [0.0, 845.4878371151332, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Cozy Corners
# Proposed budget: 1059.7630301423458
# Optimal t: [97.17479213285316, 0.0, 361.9397051429335]
# Dual values: [0.0, 0.0, 0.663969955056858, 0.6546469512569034]
#
# Company: Fitness Front
# Proposed budget: 2374.0819457016282
# Optimal t: [0.0, 898.9574236520585, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Pixel Pioneers
# Proposed budget: 2424.093585202158
# Optimal t: [0.0, 917.8945688838863, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Vigor Valley
# Proposed budget: 2165.2098042582384
# Optimal t: [0.0, 819.8669935661896, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Dine Divine
# Proposed budget: 1635.674797782039
# Optimal t: [0.0, 619.3560440527194, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Heal Hub
# Proposed budget: 1055.7660580150327
# Optimal t: [0.0, 308.72375173988934, 105.31470740436048]
# Dual values: [2.8171893853441636, 0.11538566993997924, 0.0, 0.0]
#
# Company: Fiber Fashion
# Proposed budget: 1453.2384631740667
# Optimal t: [84.46646848814461, 0.0, 547.6480795692256]
# Dual values: [0.0, 1.2438892558612822, 0.0, 0.31341419437041973]
#
# Company: Quantum Quirks
# Proposed budget: 1429.2536102874951
# Optimal t: [0.0, 483.17977060807004, 67.10503200623187]
# Dual values: [2.818622454011731, 0.0, 0.08039597348061477, 0.0]
#
# Company: Tech Titans
# Proposed budget: 2421.1517240550684
# Optimal t: [0.0, 916.7806191643671, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Trend Tailors
# Proposed budget: 2203.453999170408
# Optimal t: [0.0, 834.3483399199404, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Innovate Infinity
# Proposed budget: 1167.8888264766751
# Optimal t: [171.20041442176014, 0.0, 331.42273445255887]
# Dual values: [0.0, 1.2438892558612822, 0.0, 0.31341419437041973]
#
# Company: Runway Rebels
# Proposed budget: 860.3410052155498
# Optimal t: [307.69920163974194, 0.0, 53.12196193945563]
# Dual values: [0.0, 0.0, 0.663969955056858, 0.6546469512569034]
#
# Company: Giga Geeks
# Proposed budget: 1089.0608321494112
# Optimal t: [0.0, 26.453026463232657, 446.40177943231447]
# Dual values: [2.818622454011731, 0.0, 0.08039597348061477, 0.0]
#
# Company: Palate Paradise
# Proposed budget: 2630.023865498458
# Optimal t: [0.0, 995.8710492502358, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Homely Haven
# Proposed budget: 1772.516161510548
# Optimal t: [0.0, 623.2183363087871, 55.467913873415135]
# Dual values: [2.8171893853441636, 0.11538566993997924, 0.0, 0.0]
#
# Company: Attire Artistry
# Proposed budget: 1662.1515481058489
# Optimal t: [0.0, 629.381591528393, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Culinary Quest
# Proposed budget: 1360.322763101956
# Optimal t: [0.0, 0.0, 595.8107623308435]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Nest Neat
# Proposed budget: 1038.819501365485
# Optimal t: [0.0, 0.0, 454.9948407989162]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Domestic Dream
# Proposed budget: 1276.9138980288149
# Optimal t: [0.0, 0.0, 559.2783298579378]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Mode Maven
# Proposed budget: 733.9980126436418
# Optimal t: [0.0, 0.0, 321.48540576156995]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Epicurean Edge
# Proposed budget: 1495.2934720384935
# Optimal t: [0.0, 0.0, 654.9268803324545]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Pulse Point
# Proposed budget: 1383.1386837329396
# Optimal t: [0.0, 202.2665653683654, 371.8410229046901]
# Dual values: [2.8171893853441636, 0.11538566993997924, 0.0, 0.0]
#
# Company: Code Crafters
# Proposed budget: 1261.5924635793633
# Optimal t: [31.361979402062296, 0.0, 519.574743622069]
# Dual values: [0.0, 1.2438892558612822, 0.0, 0.31341419437041973]
#
# Company: Feast Flavors
# Proposed budget: 1220.186788530227
# Optimal t: [175.20450511067506, 0.0, 350.11651590908247]
# Dual values: [0.0, 0.0, 0.6639699550568579, 0.6546469512569035]
#
# Company: Space Spruce
# Proposed budget: 1319.3765929751414
# Optimal t: [0.0, 0.0, 577.8766591168717]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Nosh Nirvana
# Proposed budget: 603.548305171437
# Optimal t: [15.810669710612874, 0.0, 247.7165685878102]
# Dual values: [0.0, 1.2438892558612822, 0.0, 0.31341419437041973]
#
# Company: Style Sphere
# Proposed budget: 1049.402055780247
# Optimal t: [0.0, 58.30103917338919, 392.1927596198829]
# Dual values: [2.8171893853441636, 0.11538566993997924, 0.0, 0.0]
#
# Company: Cyber Circuit
# Proposed budget: 2555.282929931534
# Optimal t: [0.0, 948.7715723037799, 21.74429714115426]
# Dual values: [2.8171893853441636, 0.11538566993997924, 0.0, 0.0]
#
# Company: Gourmet Grove
# Proposed budget: 2253.465638670938
# Optimal t: [0.0, 853.2854851517681, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Well Wish
# Proposed budget: 1378.5210609360959
# Optimal t: [0.0, 0.0, 603.7814748703865]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: NexGen Nerds
# Proposed budget: 1326.779377337589
# Optimal t: [0.0, 502.39132350319505, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Glam Garments
# Proposed budget: 2206.3958603174983
# Optimal t: [0.0, 835.4622896394596, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Balance Beam
# Proposed budget: 1700.3957430180187
# Optimal t: [0.0, 643.8629378821436, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Wellness Waves
# Proposed budget: 2815.3611177651283
# Optimal t: [0.0, 1066.0498815799506, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Aura Align
# Proposed budget: 688.3077364566537
# Optimal t: [166.28826859321916, 0.0, 126.53755227470465]
# Dual values: [0.0, 1.2438892558612822, 0.0, 0.31341419437041973]
#
# Company: Bistro Bliss
# Proposed budget: 686.4639236023521
# Optimal t: [42.26661495016346, 0.0, 256.2012113963778]
# Dual values: [0.0, 0.0, 0.663969955056858, 0.6546469512569034]
#
# Company: Savor Street
# Proposed budget: 2477.047085849778
# Optimal t: [0.0, 937.9456638352333, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Living Luxe
# Proposed budget: 1169.240635843487
# Optimal t: [0.0, 0.0, 512.1182806656414]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Elixir Essence
# Proposed budget: 1451.3142522726555
# Optimal t: [0.0, 0.0, 635.6643250285588]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]
#
# Company: Gadget Giants
# Proposed budget: 963.2768341672895
# Optimal t: [0.0, 0.0, 421.9077416539844]
# Dual values: [0.0, 0.0, 1.0632194637608052, 0.0]
#
# Company: Vital Vigor
# Proposed budget: 2322.129005911238
# Optimal t: [0.0, 805.2266258012453, 85.66398680411481]
# Dual values: [2.8171893853441636, 0.11538566993997924, 0.0, 0.0]
#
# Company: Decor Dreams
# Proposed budget: 2241.698194082578
# Optimal t: [0.0, 848.829686273691, 0.0]
# Dual values: [2.941861147089998, 0.0, 0.0, 0.0]
#
# Company: Chic Couture
# Proposed budget: 524.7175875510333
# Optimal t: [0.0, 0.0, 229.8222115568248]
# Dual values: [0.0, 1.5165248195116567, 0.0, 0.0]

# %% [markdown]
# Baselines - Random

# %%
platforms_l = ["Facebook", "Instagram", "Twitter"] # keept this order
companies_l = collect(keys(budget_dict)) # keept this order
age_groups = ["18-24", "25-34", "35-44", "45-60"]

baseline_random = Dict() # dict of company -> {t -> [t_p], optimal_value -> value}

for i in 1:length(companies_l)
    company = companies_l[i]

    # for each age group, pick a random platform
    t = [0.0, 0.0, 0.0]
    for a in 1:length(age_groups)
        # Calculate how much t is needed to meet that age gr demand
        platform_i = rand(1:3)
        platform = platforms_l[platform_i]

        t_needed = demand_dict[company, age_groups[a]] * platform_variables[platform, "f_p"] / impressions_per_age[platform, age_groups[a]]
        t[platform_i] += t_needed
    end

    baseline_random[company] = Dict()
    baseline_random[company]["t"] = t
    baseline_random[company]["random_budget"] = sum(platform_variables[platforms_l[p], "s_p"] * (platform_variables[platforms_l[p], "w_p"]*(platform_variables[platforms_l[p], "i_p"]*t[p])/platform_variables[platforms_l[p], "f_p"]) for p in 1:length(platforms_l))
end

# %%
for (company, solution) in baseline_random
    println("Company: ", company)
    println("Optimal budget: ", solution["random_budget"])
    println("Optimal t: ", solution["t"])
    println()
end
# Out:
# Company: Silk & Style
# Optimal budget: 4251.331611422518
# Optimal t: [414.7921413373871, 501.2773737836757, 845.8567299611377]
#
# Company: Vogue Visions
# Optimal budget: 4662.5295104943525
# Optimal t: [0.0, 956.7636133569202, 935.4574257020481]
#
# Company: Hearth Harmony
# Optimal budget: 2662.950177034203
# Optimal t: [503.79725469309267, 517.9866195764649, 37.1966585178676]
#
# Company: Silicon Saga
# Optimal budget: 5027.629379613858
# Optimal t: [0.0, 679.6760730534878, 1415.8771211175329]
#
# Company: Furnish Fine
# Optimal budget: 5027.355721171428
# Optimal t: [375.6687446392359, 992.8968703388114, 658.2480105572641]
#
# Company: Gastronomy Guild
# Optimal budget: 4955.4336297748
# Optimal t: [629.1283439345392, 322.81604185308504, 1135.1927318009134]
#
# Company: Dwell Delight
# Optimal budget: 5361.770866204315
# Optimal t: [303.04634987542835, 0.0, 2029.6079556668153]
#
# Company: Cozy Corners
# Optimal budget: 3678.8499852581695
# Optimal t: [342.3419150765511, 935.0272019466399, 169.6111493396659]
#
# Company: Fitness Front
# Optimal budget: 5276.461075899477
# Optimal t: [1894.3205789367425, 275.1058821164439, 0.0]
#
# Company: Pixel Pioneers
# Optimal budget: 4250.473100898001
# Optimal t: [756.6082250077486, 917.8945688838863, 3.9853562697715286]
#
# Company: Vigor Valley
# Optimal budget: 5883.151287526686
# Optimal t: [2167.1334620363878, 256.7135041945395, 0.0]
#
# Company: Dine Divine
# Optimal budget: 3747.3350756242216
# Optimal t: [1445.2557956658673, 0.0, 120.8891401830697]
#
# Company: Heal Hub
# Optimal budget: 3352.438304577839
# Optimal t: [0.0, 100.28405561897745, 1352.3426734254417]
#
# Company: Fiber Fashion
# Optimal budget: 4479.5664335664915
# Optimal t: [5.49565919463212, 1330.9789198394571, 416.68250861398235]
#
# Company: Quantum Quirks
# Optimal budget: 4688.627124338724
# Optimal t: [791.6392073541462, 587.897108664875, 540.7506975059122]
#
# Company: Tech Titans
# Optimal budget: 3840.6448050471427
# Optimal t: [174.17395679333305, 1295.8702811536182, 0.0]
#
# Company: Trend Tailors
# Optimal budget: 5207.719252478781
# Optimal t: [1579.940594701614, 0.0, 618.8371185915562]
#
# Company: Innovate Infinity
# Optimal budget: 5489.681545815527
# Optimal t: [433.37198220527574, 749.520954013776, 1081.5534634123837]
#
# Company: Runway Rebels
# Optimal budget: 3406.3209131138688
# Optimal t: [27.80550934921588, 735.7673244079398, 611.6240751843864]
#
# Company: Giga Geeks
# Optimal budget: 4244.80043415589
# Optimal t: [1638.480382801395, 0.0, 135.50211317223196]
#
# Company: Palate Paradise
# Optimal budget: 4008.698545356472
# Optimal t: [126.20450547790682, 114.81797672317708, 1490.2004657353896]
#
# Company: Homely Haven
# Optimal budget: 4190.6952099206865
# Optimal t: [175.84494429921682, 337.9136656726414, 1259.6355563600946]
#
# Company: Attire Artistry
# Optimal budget: 2846.8028200947897
# Optimal t: [0.0, 392.30631438820217, 793.0943970401634]
#
# Company: Culinary Quest
# Optimal budget: 4120.668378305719
# Optimal t: [0.0, 1058.0641238519675, 580.9515745098792]
#
# Company: Nest Neat
# Optimal budget: 1972.2648142903352
# Optimal t: [129.65307655756766, 0.0, 727.4410964311353]
#
# Company: Domestic Dream
# Optimal budget: 3584.9163837068977
# Optimal t: [525.672213890547, 868.0834157903705, 13.039091353544771]
#
# Company: Mode Maven
# Optimal budget: 2012.5909969482364
# Optimal t: [96.50147362374922, 579.2987916496136, 109.90091283702021]
#
# Company: Epicurean Edge
# Optimal budget: 4296.860946127231
# Optimal t: [0.0, 0.0, 1881.9915871317476]
#
# Company: Pulse Point
# Optimal budget: 4505.698641399705
# Optimal t: [1319.9512298317027, 224.2192449619572, 325.5116020045641]
#
# Company: Code Crafters
# Optimal budget: 3727.5065430263544
# Optimal t: [0.0, 744.6175869291103, 771.3152232291602]
#
# Company: Feast Flavors
# Optimal budget: 4203.865073495692
# Optimal t: [186.46047445944765, 844.6177403906927, 668.1286713936804]
#
# Company: Space Spruce
# Optimal budget: 4911.966888292963
# Optimal t: [866.2675528086547, 1072.0845470937556, 0.0]
#
# Company: Nosh Nirvana
# Optimal budget: 2298.3316484598918
# Optimal t: [28.263390143822335, 605.6023036198488, 276.4143760508712]
#
# Company: Style Sphere
# Optimal budget: 3433.4734080606877
# Optimal t: [485.73512950554516, 0.0, 992.8394394089652]
#
# Company: Cyber Circuit
# Optimal budget: 5679.275284889847
# Optimal t: [1687.6908283051112, 68.30942918973827, 633.007420848711]
#
# Company: Gourmet Grove
# Optimal budget: 4586.0542849784515
# Optimal t: [0.0, 1736.5312735800755, 0.0]
#
# Company: Well Wish
# Optimal budget: 5415.757733327741
# Optimal t: [729.3546638634579, 937.1589369993429, 520.7585758748457]
#
# Company: NexGen Nerds
# Optimal budget: 4486.148301504258
# Optimal t: [1050.2302987530095, 743.5354354865889, 0.0]
#
# Company: Glam Garments
# Optimal budget: 6153.727884260032
# Optimal t: [0.0, 1138.0920530850117, 1378.8470041849491]
#
# Company: Balance Beam
# Optimal budget: 3900.841203672023
# Optimal t: [890.3077026693453, 0.0, 771.9310576246211]
#
# Company: Wellness Waves
# Optimal budget: 4740.00343341497
# Optimal t: [58.47475420476349, 1584.63177961149, 181.61591528151646]
#
# Company: Aura Align
# Optimal budget: 2705.217778685039
# Optimal t: [345.44143509116185, 710.1706802354846, 0.0]
#
# Company: Bistro Bliss
# Optimal budget: 2502.679475200499
# Optimal t: [23.273244226695365, 438.9244173468288, 563.9640812031747]
#
# Company: Savor Street
# Optimal budget: 5004.508068388483
# Optimal t: [0.0, 0.0, 2191.935508392222]
#
# Company: Living Luxe
# Optimal budget: 3990.2292773031304
# Optimal t: [919.215696085691, 232.17028201734573, 512.1182806656414]
#
# Company: Elixir Essence
# Optimal budget: 2567.883482270364
# Optimal t: [283.4189956088851, 160.40875961077626, 641.0093543997082]
#
# Company: Gadget Giants
# Optimal budget: 3329.1888302923044
# Optimal t: [128.24432936330498, 1143.9772303400348, 0.0]
#
# Company: Vital Vigor
# Optimal budget: 6181.428278474437
# Optimal t: [1356.6439990618424, 1106.7833997365508, 0.0]
#
# Company: Decor Dreams
# Optimal budget: 5055.986857246516
# Optimal t: [0.0, 1525.56853518244, 449.8486516972946]
#
# Company: Chic Couture
# Optimal budget: 1266.3513446945785
# Optimal t: [308.7724992004575, 0.0, 229.82221155682478]

# %% [markdown]
# Baseline - Greedy

# %%
platforms_l = ["Facebook", "Instagram", "Twitter"] # keept this order
companies_l = collect(keys(budget_dict)) # keept this order
age_groups = ["18-24", "25-34", "35-44", "45-60"]

baseline_greedy = Dict() # dict of company -> {t -> [t_p], optimal_value -> value}

for i in 1:length(companies_l)
    company = companies_l[i]

    # for each age group, pick a random platform
    t = [0.0, 0.0, 0.0]
    for a in 1:length(age_groups)
        # Calculate how much t is needed to meet that age gr demand
        all_impressions = [impressions_per_age[platforms_l[p], age_groups[a]] for p in 1:length(platforms_l)]
        platform_i = argmax(all_impressions)
        platform = platforms_l[platform_i]

        t_needed = demand_dict[company, age_groups[a]] * platform_variables[platform, "f_p"] / impressions_per_age[platform, age_groups[a]]
        t[platform_i] += t_needed
    end

    baseline_greedy[company] = Dict()
    baseline_greedy[company]["t"] = t
    baseline_greedy[company]["greedy_budget"] = sum(platform_variables[platforms_l[p], "s_p"] * (platform_variables[platforms_l[p], "w_p"]*(platform_variables[platforms_l[p], "i_p"]*t[p])/platform_variables[platforms_l[p], "f_p"]) for p in 1:length(platforms_l))
end

# %%
for (company, solution) in baseline_greedy
    println("Company: ", company)
    println("Optimal budget: ", solution["greedy_budget"])
    println("Optimal t: ", solution["t"])
    println()
end
# Out:
# Company: Silk & Style
# Optimal budget: 4290.258835989907
# Optimal t: [0.0, 893.2635006143314, 845.8567299611377]
#
# Company: Vogue Visions
# Optimal budget: 3796.1886621810054
# Optimal t: [0.0, 712.900189863994, 838.0851569646285]
#
# Company: Hearth Harmony
# Optimal budget: 2372.378060999512
# Optimal t: [0.0, 714.3772348445622, 212.75870995666682]
#
# Company: Silicon Saga
# Optimal budget: 4272.701857188223
# Optimal t: [0.0, 788.2891702056545, 959.5913401918096]
#
# Company: Furnish Fine
# Optimal budget: 4543.916162208385
# Optimal t: [0.0, 907.5328654046615, 940.4512019946974]
#
# Company: Gastronomy Guild
# Optimal budget: 4599.141693697969
# Optimal t: [0.0, 1248.599117843383, 570.1261988656901]
#
# Company: Dwell Delight
# Optimal budget: 4510.703310233743
# Optimal t: [0.0, 1104.6916451207999, 697.8495030155946]
#
# Company: Cozy Corners
# Optimal budget: 2763.2960587077932
# Optimal t: [0.0, 421.74567058139496, 722.4664089863447]
#
# Company: Fitness Front
# Optimal budget: 4134.3766256908475
# Optimal t: [0.0, 1174.0633057685025, 452.778738861855]
#
# Company: Pixel Pioneers
# Optimal budget: 3889.529892949701
# Optimal t: [0.0, 1275.2936845236018, 228.44400028436368]
#
# Company: Vigor Valley
# Optimal budget: 4169.13591188605
# Optimal t: [0.0, 1086.226734921706, 569.6041171554064]
#
# Company: Dine Divine
# Optimal budget: 3046.4897151420964
# Optimal t: [0.0, 958.0702226122718, 226.1332346795382]
#
# Company: Heal Hub
# Optimal budget: 2676.0246243393285
# Optimal t: [0.0, 694.7299897259342, 368.4796216921735]
#
# Company: Fiber Fashion
# Optimal budget: 3310.100558852138
# Optimal t: [0.0, 712.5049133323498, 625.6395769677065]
#
# Company: Quantum Quirks
# Optimal budget: 3124.045752632098
# Optimal t: [0.0, 765.3586684731356, 483.0127709445403]
#
# Company: Tech Titans
# Optimal budget: 3493.3881443413775
# Optimal t: [0.0, 1057.5139750447443, 306.84408400126165]
#
# Company: Trend Tailors
# Optimal budget: 3880.5685498686953
# Optimal t: [0.0, 958.3845179840018, 591.0897127561179]
#
# Company: Innovate Infinity
# Optimal budget: 3540.2538420004894
# Optimal t: [0.0, 700.8305659009316, 739.9487070857708]
#
# Company: Runway Rebels
# Optimal budget: 1970.374650748636
# Optimal t: [0.0, 337.37617930013926, 472.7637060833222]
#
# Company: Giga Geeks
# Optimal budget: 3098.6999124211507
# Optimal t: [0.0, 655.6124964769523, 598.8555380571265]
#
# Company: Palate Paradise
# Optimal budget: 3789.354371330848
# Optimal t: [0.0, 1115.136605081064, 369.8225458337339]
#
# Company: Homely Haven
# Optimal budget: 3744.685329611887
# Optimal t: [0.0, 835.6604558887077, 673.5295717694562]
#
# Company: Attire Artistry
# Optimal budget: 2755.3491947747843
# Optimal t: [0.0, 995.5268479290357, 55.289656633777575]
#
# Company: Culinary Quest
# Optimal budget: 2898.7104819814126
# Optimal t: [0.0, 538.6351799675288, 646.5700822428571]
#
# Company: Nest Neat
# Optimal budget: 1816.463571445602
# Optimal t: [0.0, 228.83595019301072, 530.9009797499089]
#
# Company: Domestic Dream
# Optimal budget: 2349.5320226293125
# Optimal t: [0.0, 394.8793489259999, 572.3174212114826]
#
# Company: Mode Maven
# Optimal budget: 1370.5685995471977
# Optimal t: [0.0, 146.02850771106188, 431.38631859859015]
#
# Company: Epicurean Edge
# Optimal budget: 3899.9910162894867
# Optimal t: [0.0, 583.2419686376188, 1033.526211419308]
#
# Company: Pulse Point
# Optimal budget: 3835.086207166263
# Optimal t: [0.0, 736.6361159408257, 827.6664919957766]
#
# Company: Code Crafters
# Optimal budget: 3727.5065430263544
# Optimal t: [0.0, 744.6175869291103, 771.3152232291602]
#
# Company: Feast Flavors
# Optimal budget: 2490.86006052387
# Optimal t: [0.0, 474.84813919844703, 541.7176261387648]
#
# Company: Space Spruce
# Optimal budget: 3271.2395460188254
# Optimal t: [0.0, 642.0572542322468, 690.1059811241677]
#
# Company: Nosh Nirvana
# Optimal budget: 1542.445749919645
# Optimal t: [0.0, 343.3107704964838, 278.4696077409831]
#
# Company: Style Sphere
# Optimal budget: 3040.958417568376
# Optimal t: [0.0, 482.82680688218045, 773.4274446230789]
#
# Company: Cyber Circuit
# Optimal budget: 4767.516297571115
# Optimal t: [0.0, 1220.1488867568598, 676.7815132498971]
#
# Company: Gourmet Grove
# Optimal budget: 3776.1419954943567
# Optimal t: [0.0, 1046.4956855977098, 443.4329865636647]
#
# Company: Well Wish
# Optimal budget: 3378.8305500531887
# Optimal t: [0.0, 725.6218491526157, 640.570339760745]
#
# Company: NexGen Nerds
# Optimal budget: 3197.0452517627436
# Optimal t: [0.0, 797.7723501108798, 477.49288468205634]
#
# Company: Glam Garments
# Optimal budget: 4393.609360836053
# Optimal t: [0.0, 1031.8529049075569, 730.8162687161873]
#
# Company: Balance Beam
# Optimal budget: 3126.675265357235
# Optimal t: [0.0, 681.2328120424697, 581.4733536549019]
#
# Company: Wellness Waves
# Optimal budget: 4138.765608802144
# Optimal t: [0.0, 1121.3095891149007, 515.7216158973629]
#
# Company: Aura Align
# Optimal budget: 1846.3662071052863
# Optimal t: [0.0, 285.40777369672855, 478.56113750858657]
#
# Company: Bistro Bliss
# Optimal budget: 1655.8977633643203
# Optimal t: [0.0, 366.04590928430576, 301.8628351631425]
#
# Company: Savor Street
# Optimal budget: 4359.379482225424
# Optimal t: [0.0, 1255.9871460507754, 456.56644391891024]
#
# Company: Living Luxe
# Optimal budget: 3200.221755078432
# Optimal t: [0.0, 497.2903152629342, 826.4535186528814]
#
# Company: Elixir Essence
# Optimal budget: 2266.113824962573
# Optimal t: [0.0, 163.19162258016226, 803.7754671224752]
#
# Company: Gadget Giants
# Optimal budget: 1945.1737765669332
# Optimal t: [0.0, 101.33322054683472, 734.7582088310494]
#
# Company: Vital Vigor
# Optimal budget: 4115.183692688734
# Optimal t: [0.0, 942.2744849686285, 712.4838864161479]
#
# Company: Decor Dreams
# Optimal budget: 4490.272589337177
# Optimal t: [0.0, 1042.0398867196327, 761.3706667844358]
#
# Company: Chic Couture
# Optimal budget: 982.3291979041655
# Optimal t: [0.0, 38.81071521147472, 385.3599441312517]
